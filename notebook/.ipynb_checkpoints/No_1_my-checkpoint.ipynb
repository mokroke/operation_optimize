# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np
import pickle

# %%
input_path = '../input/'
status_file_name = 'status.csv'
station_file_name = 'station.csv'
trip_file_name = 'trip.csv'
weather_file_name = 'weather.csv'
output_path = '../output/'
model_path = '../model/'

#ジェネレータ使えそう
submit_file_name_1 = 'submission_1_No_1_my.csv'
submit_file_name_2 = 'submission_2_No_2_my.csv'

#modelの名前
model_name_1 = 'model_1_No_1_my.sav'

# %%
status = pd.read_csv(input_path + status_file_name)
station = pd.read_csv(input_path + station_file_name)
weather = pd.read_csv(input_path + weather_file_name)

# %%
#statusのyear, month, dayを結合してdatetime型に
status['date'] = status['year'].astype(str) + '/' + status['month'].astype(str).str.zfill(2).astype(str) + '/' + status['day'].astype(str).str.zfill(2).astype(str)
status['date'] = pd.to_datetime(status['date'])

weather['date'] = pd.to_datetime(weather['date'])

train_sta_wea = pd.merge(status,weather, on = 'date', how ='left')

train_sta_wea['events'] = train_sta_wea['events'].fillna('なし')

le = preprocessing.LabelEncoder()
train_sta_wea['events'] = le.fit_transform(train_sta_wea['events'].values.tolist())
train_sta_wea = pd.merge(train_sta_wea, station[['station_id', 'city']], how = 'left')

# %%
train_sta_wea_pre_1 = train_sta_wea[train_sta_wea['predict'] == 1]

train_sta_wea_pre_0 = train_sta_wea[train_sta_wea['predict'] == 0]

# %%
#曜日を追加
train_sta_wea['date']=pd.to_datetime(train_sta_wea['date'])
train_sta_wea['weekday']=train_sta_wea['date'].dt.weekday

# %%
from datetime import date
from datetime import datetime as dt
from dateutil.relativedelta import relativedelta
class make_tr_va_te():
    def __init__(self, df, train_end_next_date):
        self.df = df
        self.train_end_next_date = train_end_next_date
        
    def make_train_data(self):
        train_all = self.df[self.df['predict'] == 0]
        train = train_all[train_all['date'] < self.train_end_next_date]
        train_notna = train[train['bikes_available'].notna()]
        return train_notna
        
    def make_valid_data(self):
        valid_all = self.df[self.df['predict'] == 0]
        valid = valid_all[(self.train_end_next_date <= valid_all['date']) & (valid_all['date'] < (self.train_end_next_date + relativedelta(months = 1)))]
        valid_notna = valid[valid['bikes_available'].notna()]
        return valid_notna
                                      
    def make_test_data(self):
        test_all = self.df[self.df['predict'] == 1]
        test = test_all[((self.train_end_next_date + relativedelta(months = 1)) <= test_all['date']) & (test_all['date']< (self.train_end_next_date + relativedelta(months = 2)))]
        return test
    
    def model_for_data(self):
        train = self.make_train_data()
        valid = self.make_valid_data()
        
        tr_X = train.drop(['id','predict','bikes_available','city','date'],axis=1)
        tr_y = train['bikes_available']
        va_X = valid.drop(['id','predict','bikes_available','city','date'],axis=1)
        va_y = valid['bikes_available']   
        return tr_X, tr_y, va_X, va_y
    
    def predict_for_data(self):
        test = self.make_test_data()
        te_X = test.drop(['id','predict','bikes_available','city','date'],axis=1)       
        return te_X
    
    def make_fit_model(self):
        tr_X, tr_y, va_X, va_y = self.model_for_data()
        import lightgbm as lgb
        lgb_train = lgb.Dataset(tr_X, tr_y)
        lgb_eval = lgb.Dataset(va_X, va_y)

        params = {
            'task':'train',
            'boosting_type':'gbdt',
            'objective':'regression',
            'metric':{'rmse'},
            'learning_rate':0.01,
            'num_leaves':23,
            'min_data_in_leaf':1,
            'num_iteration': 10000,
            'verbose':0,
            'random_seed':0,
        }

        model = lgb.train(params, lgb_train, valid_sets=[lgb_train, lgb_eval],
                         verbose_eval=100, num_boost_round=10000,
                         early_stopping_rounds=100)
        
        return model
    
    def model_and_valid_score(self):
        model = self.make_fit_model()
        valid_best_score = model.best_score['valid_1']['rmse']
        
        return model, valid_best_score
    
    def predict(self, model_file_name):
        import pickle
        test = self.make_test_data()
        te_X = self.predict_for_data()
        model = self.make_fit_model()
        pickle.dump(model, open(model_path + model_file_name, 'wb'))
        valid_best_score = model.best_score['valid_1']['rmse']
        y_pred = model.predict(te_X)
        sub_index = test['id']
        sub_df = pd.DataFrame(list(zip(sub_index, y_pred)))
        print('*****')
        print(valid_best_score)
        return sub_df,valid_best_score

# %%
def month_range(start, stop, step = relativedelta(months = 1)):
    current = start
    while current < stop:
        yield current
        current += step

# %%
# s = []
# s.append(8)

# make_data = make_tr_va_te(train_sta_wea, dt(2014,8,1))
# sub_df, valid_best_score = make_data.predict()
# # sub_df_all = pd.concat([sub_df_all, sub_df])
# valid_list.append(valid_best_score)

# tr_X, tr_y, va_X, va_y = make_data.model_for_data()

# model = make_data.make_fit_model()

# valid_best_score = model.best_score['valid_1']['rmse']
# #これをリストに格納して、最後に平均出せばできる

# s = [7,3,4]

# cv_score = sum(s)/len(s)

# cv_score

# %%
from datetime import date
from datetime import datetime as dt
from dateutil.relativedelta import relativedelta
sub_df_all = pd.DataFrame()
valid_score_list = []
#train_end_next_dateにはvalidationの一ヶ月の初めを入れる
for d in month_range(dt(2014,8,1), dt(2015,8,1)):
    make_data = make_tr_va_te(train_sta_wea, d)
    sub_df, valid_best_score = make_data.predict(model_name_1)
    sub_df_all = pd.concat([sub_df_all, sub_df])
    valid_score_list.append(valid_best_score)
cv_score = sum(valid_score_list)/len(valid_score_list)
print(f'CV score is {cv_score}')
# Out:
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018131 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.31586	valid_1's rmse: 3.54073
# [200]	training's rmse: 3.19777	valid_1's rmse: 3.41203
# [300]	training's rmse: 3.13157	valid_1's rmse: 3.33931
# [400]	training's rmse: 3.08205	valid_1's rmse: 3.29959
# [500]	training's rmse: 3.05099	valid_1's rmse: 3.27768
# [600]	training's rmse: 3.02734	valid_1's rmse: 3.26234
# [700]	training's rmse: 3.00967	valid_1's rmse: 3.2527
# [800]	training's rmse: 2.98859	valid_1's rmse: 3.24126
# [900]	training's rmse: 2.96894	valid_1's rmse: 3.23002
# [1000]	training's rmse: 2.95247	valid_1's rmse: 3.22323
# [1100]	training's rmse: 2.93781	valid_1's rmse: 3.2177
# [1200]	training's rmse: 2.92544	valid_1's rmse: 3.21344
# [1300]	training's rmse: 2.91457	valid_1's rmse: 3.21142
# [1400]	training's rmse: 2.90488	valid_1's rmse: 3.20953
# [1500]	training's rmse: 2.89016	valid_1's rmse: 3.20484
# [1600]	training's rmse: 2.8782	valid_1's rmse: 3.20332
# [1700]	training's rmse: 2.8647	valid_1's rmse: 3.20066
# [1800]	training's rmse: 2.85308	valid_1's rmse: 3.19931
# [1900]	training's rmse: 2.84146	valid_1's rmse: 3.19778
# [2000]	training's rmse: 2.8319	valid_1's rmse: 3.1963
# [2100]	training's rmse: 2.8233	valid_1's rmse: 3.19446
# [2200]	training's rmse: 2.81465	valid_1's rmse: 3.1937
# [2300]	training's rmse: 2.80453	valid_1's rmse: 3.19252
# [2400]	training's rmse: 2.7947	valid_1's rmse: 3.19102
# [2500]	training's rmse: 2.78641	valid_1's rmse: 3.19043
# [2600]	training's rmse: 2.77922	valid_1's rmse: 3.18951
# [2700]	training's rmse: 2.77103	valid_1's rmse: 3.188
# [2800]	training's rmse: 2.76407	valid_1's rmse: 3.18707
# [2900]	training's rmse: 2.75742	valid_1's rmse: 3.18716
# Early stopping, best iteration is:
# [2805]	training's rmse: 2.76377	valid_1's rmse: 3.18703
# *****
# 3.187034875562724
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021363 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.33567	valid_1's rmse: 3.71788
# [200]	training's rmse: 3.20808	valid_1's rmse: 3.59304
# [300]	training's rmse: 3.14356	valid_1's rmse: 3.52658
# [400]	training's rmse: 3.10069	valid_1's rmse: 3.48718
# [500]	training's rmse: 3.07236	valid_1's rmse: 3.4682
# [600]	training's rmse: 3.04663	valid_1's rmse: 3.45334
# [700]	training's rmse: 3.02442	valid_1's rmse: 3.44408
# [800]	training's rmse: 3.00522	valid_1's rmse: 3.43695
# [900]	training's rmse: 2.98871	valid_1's rmse: 3.43099
# [1000]	training's rmse: 2.97371	valid_1's rmse: 3.42372
# [1100]	training's rmse: 2.96125	valid_1's rmse: 3.41921
# [1200]	training's rmse: 2.94836	valid_1's rmse: 3.41504
# [1300]	training's rmse: 2.93596	valid_1's rmse: 3.4107
# [1400]	training's rmse: 2.92535	valid_1's rmse: 3.40776
# [1500]	training's rmse: 2.91402	valid_1's rmse: 3.40456
# [1600]	training's rmse: 2.90196	valid_1's rmse: 3.40087
# [1700]	training's rmse: 2.89119	valid_1's rmse: 3.39919
# [1800]	training's rmse: 2.88101	valid_1's rmse: 3.39621
# [1900]	training's rmse: 2.8704	valid_1's rmse: 3.39379
# [2000]	training's rmse: 2.85846	valid_1's rmse: 3.39076
# [2100]	training's rmse: 2.84824	valid_1's rmse: 3.38793
# [2200]	training's rmse: 2.83899	valid_1's rmse: 3.3842
# [2300]	training's rmse: 2.83067	valid_1's rmse: 3.38217
# [2400]	training's rmse: 2.82261	valid_1's rmse: 3.37948
# [2500]	training's rmse: 2.81404	valid_1's rmse: 3.37837
# [2600]	training's rmse: 2.80686	valid_1's rmse: 3.37693
# [2700]	training's rmse: 2.79965	valid_1's rmse: 3.37642
# [2800]	training's rmse: 2.79267	valid_1's rmse: 3.37468
# [2900]	training's rmse: 2.78663	valid_1's rmse: 3.37368
# [3000]	training's rmse: 2.78055	valid_1's rmse: 3.37311
# [3100]	training's rmse: 2.77392	valid_1's rmse: 3.37324
# Early stopping, best iteration is:
# [3069]	training's rmse: 2.77583	valid_1's rmse: 3.37275
# *****
# 3.3727508950805247
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019595 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.34563	valid_1's rmse: 4.02738
# [200]	training's rmse: 3.21653	valid_1's rmse: 3.91283
# [300]	training's rmse: 3.15227	valid_1's rmse: 3.85655
# [400]	training's rmse: 3.10907	valid_1's rmse: 3.83416
# [500]	training's rmse: 3.08393	valid_1's rmse: 3.83139
# [600]	training's rmse: 3.06173	valid_1's rmse: 3.82498
# [700]	training's rmse: 3.04101	valid_1's rmse: 3.81709
# [800]	training's rmse: 3.02367	valid_1's rmse: 3.80928
# [900]	training's rmse: 3.00616	valid_1's rmse: 3.80159
# [1000]	training's rmse: 2.99358	valid_1's rmse: 3.79902
# [1100]	training's rmse: 2.97979	valid_1's rmse: 3.79529
# [1200]	training's rmse: 2.96652	valid_1's rmse: 3.79369
# [1300]	training's rmse: 2.95008	valid_1's rmse: 3.78613
# [1400]	training's rmse: 2.93464	valid_1's rmse: 3.77999
# [1500]	training's rmse: 2.92498	valid_1's rmse: 3.78067
# Early stopping, best iteration is:
# [1407]	training's rmse: 2.93348	valid_1's rmse: 3.77959
# *****
# 3.7795922843278795
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.024055 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.37041	valid_1's rmse: 3.74527
# [200]	training's rmse: 3.24388	valid_1's rmse: 3.63149
# [300]	training's rmse: 3.17987	valid_1's rmse: 3.59416
# [400]	training's rmse: 3.14	valid_1's rmse: 3.56808
# [500]	training's rmse: 3.10912	valid_1's rmse: 3.5491
# [600]	training's rmse: 3.08309	valid_1's rmse: 3.53348
# [700]	training's rmse: 3.06265	valid_1's rmse: 3.52254
# [800]	training's rmse: 3.04606	valid_1's rmse: 3.51586
# [900]	training's rmse: 3.03003	valid_1's rmse: 3.50726
# [1000]	training's rmse: 3.01698	valid_1's rmse: 3.50084
# [1100]	training's rmse: 3.00446	valid_1's rmse: 3.49546
# [1200]	training's rmse: 2.99239	valid_1's rmse: 3.48679
# [1300]	training's rmse: 2.9806	valid_1's rmse: 3.48099
# [1400]	training's rmse: 2.96819	valid_1's rmse: 3.47496
# [1500]	training's rmse: 2.95729	valid_1's rmse: 3.47237
# [1600]	training's rmse: 2.94506	valid_1's rmse: 3.47163
# [1700]	training's rmse: 2.93438	valid_1's rmse: 3.46932
# [1800]	training's rmse: 2.92515	valid_1's rmse: 3.46994
# Early stopping, best iteration is:
# [1743]	training's rmse: 2.93	valid_1's rmse: 3.46928
# *****
# 3.4692848589772325
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033776 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.37731	valid_1's rmse: 4.00317
# [200]	training's rmse: 3.24929	valid_1's rmse: 3.8754
# [300]	training's rmse: 3.18752	valid_1's rmse: 3.82928
# [400]	training's rmse: 3.14535	valid_1's rmse: 3.79082
# [500]	training's rmse: 3.11959	valid_1's rmse: 3.77547
# [600]	training's rmse: 3.09465	valid_1's rmse: 3.76256
# [700]	training's rmse: 3.07165	valid_1's rmse: 3.74963
# [800]	training's rmse: 3.05455	valid_1's rmse: 3.74104
# [900]	training's rmse: 3.04082	valid_1's rmse: 3.73658
# [1000]	training's rmse: 3.02691	valid_1's rmse: 3.73045
# [1100]	training's rmse: 3.01424	valid_1's rmse: 3.72392
# [1200]	training's rmse: 2.99986	valid_1's rmse: 3.71782
# [1300]	training's rmse: 2.98843	valid_1's rmse: 3.71291
# [1400]	training's rmse: 2.97682	valid_1's rmse: 3.70849
# [1500]	training's rmse: 2.96527	valid_1's rmse: 3.70393
# [1600]	training's rmse: 2.95405	valid_1's rmse: 3.69953
# [1700]	training's rmse: 2.94322	valid_1's rmse: 3.69635
# [1800]	training's rmse: 2.93196	valid_1's rmse: 3.69282
# [1900]	training's rmse: 2.9213	valid_1's rmse: 3.6915
# [2000]	training's rmse: 2.91212	valid_1's rmse: 3.68922
# [2100]	training's rmse: 2.90237	valid_1's rmse: 3.68499
# [2200]	training's rmse: 2.89283	valid_1's rmse: 3.68283
# [2300]	training's rmse: 2.88226	valid_1's rmse: 3.67748
# [2400]	training's rmse: 2.87354	valid_1's rmse: 3.67311
# [2500]	training's rmse: 2.86572	valid_1's rmse: 3.66897
# [2600]	training's rmse: 2.85823	valid_1's rmse: 3.66637
# [2700]	training's rmse: 2.85044	valid_1's rmse: 3.66483
# [2800]	training's rmse: 2.84359	valid_1's rmse: 3.66437
# [2900]	training's rmse: 2.8366	valid_1's rmse: 3.66267
# [3000]	training's rmse: 2.82953	valid_1's rmse: 3.66324
# Early stopping, best iteration is:
# [2904]	training's rmse: 2.83637	valid_1's rmse: 3.66264
# *****
# 3.6626409967677183
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026571 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.39267	valid_1's rmse: 3.7117
# [200]	training's rmse: 3.26672	valid_1's rmse: 3.61155
# [300]	training's rmse: 3.2081	valid_1's rmse: 3.59283
# [400]	training's rmse: 3.16842	valid_1's rmse: 3.56866
# [500]	training's rmse: 3.13707	valid_1's rmse: 3.54583
# [600]	training's rmse: 3.11197	valid_1's rmse: 3.53371
# [700]	training's rmse: 3.08762	valid_1's rmse: 3.51787
# [800]	training's rmse: 3.07	valid_1's rmse: 3.50869
# [900]	training's rmse: 3.05462	valid_1's rmse: 3.5029
# [1000]	training's rmse: 3.04043	valid_1's rmse: 3.49721
# [1100]	training's rmse: 3.02823	valid_1's rmse: 3.49031
# [1200]	training's rmse: 3.01465	valid_1's rmse: 3.48351
# [1300]	training's rmse: 3.00255	valid_1's rmse: 3.48246
# Early stopping, best iteration is:
# [1275]	training's rmse: 3.00514	valid_1's rmse: 3.4822
# *****
# 3.4821975222614814
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031384 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.40234	valid_1's rmse: 3.85684
# [200]	training's rmse: 3.2725	valid_1's rmse: 3.70982
# [300]	training's rmse: 3.21656	valid_1's rmse: 3.66134
# [400]	training's rmse: 3.17907	valid_1's rmse: 3.63429
# [500]	training's rmse: 3.14924	valid_1's rmse: 3.60589
# [600]	training's rmse: 3.12606	valid_1's rmse: 3.59366
# [700]	training's rmse: 3.10648	valid_1's rmse: 3.57343
# [800]	training's rmse: 3.0869	valid_1's rmse: 3.55832
# [900]	training's rmse: 3.06886	valid_1's rmse: 3.54906
# [1000]	training's rmse: 3.05375	valid_1's rmse: 3.54244
# [1100]	training's rmse: 3.04027	valid_1's rmse: 3.53663
# [1200]	training's rmse: 3.02609	valid_1's rmse: 3.52102
# [1300]	training's rmse: 3.01361	valid_1's rmse: 3.51351
# [1400]	training's rmse: 3.00118	valid_1's rmse: 3.50577
# [1500]	training's rmse: 2.98727	valid_1's rmse: 3.50179
# [1600]	training's rmse: 2.97665	valid_1's rmse: 3.49818
# [1700]	training's rmse: 2.96607	valid_1's rmse: 3.4948
# [1800]	training's rmse: 2.95579	valid_1's rmse: 3.49092
# [1900]	training's rmse: 2.94663	valid_1's rmse: 3.48818
# [2000]	training's rmse: 2.93614	valid_1's rmse: 3.48586
# [2100]	training's rmse: 2.92619	valid_1's rmse: 3.48381
# [2200]	training's rmse: 2.91755	valid_1's rmse: 3.48128
# [2300]	training's rmse: 2.90945	valid_1's rmse: 3.47964
# [2400]	training's rmse: 2.90169	valid_1's rmse: 3.47821
# [2500]	training's rmse: 2.89401	valid_1's rmse: 3.47618
# [2600]	training's rmse: 2.88704	valid_1's rmse: 3.47533
# [2700]	training's rmse: 2.88033	valid_1's rmse: 3.47492
# [2800]	training's rmse: 2.8735	valid_1's rmse: 3.47308
# [2900]	training's rmse: 2.86709	valid_1's rmse: 3.47212
# [3000]	training's rmse: 2.86093	valid_1's rmse: 3.4704
# [3100]	training's rmse: 2.85448	valid_1's rmse: 3.47014
# [3200]	training's rmse: 2.84835	valid_1's rmse: 3.47119
# Early stopping, best iteration is:
# [3125]	training's rmse: 2.85271	valid_1's rmse: 3.46976
# *****
# 3.469757901535675
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.41141	valid_1's rmse: 4.0892
# [200]	training's rmse: 3.28048	valid_1's rmse: 3.92112
# [300]	training's rmse: 3.22462	valid_1's rmse: 3.85004
# [400]	training's rmse: 3.18661	valid_1's rmse: 3.80642
# [500]	training's rmse: 3.15993	valid_1's rmse: 3.78083
# [600]	training's rmse: 3.13362	valid_1's rmse: 3.75333
# [700]	training's rmse: 3.1111	valid_1's rmse: 3.72659
# [800]	training's rmse: 3.09123	valid_1's rmse: 3.7097
# [900]	training's rmse: 3.07352	valid_1's rmse: 3.69697
# [1000]	training's rmse: 3.05985	valid_1's rmse: 3.68548
# [1100]	training's rmse: 3.04812	valid_1's rmse: 3.67896
# [1200]	training's rmse: 3.03503	valid_1's rmse: 3.67436
# [1300]	training's rmse: 3.0227	valid_1's rmse: 3.67117
# [1400]	training's rmse: 3.01059	valid_1's rmse: 3.66661
# [1500]	training's rmse: 2.99665	valid_1's rmse: 3.66224
# [1600]	training's rmse: 2.98472	valid_1's rmse: 3.65652
# [1700]	training's rmse: 2.9745	valid_1's rmse: 3.65224
# [1800]	training's rmse: 2.96452	valid_1's rmse: 3.64928
# [1900]	training's rmse: 2.95432	valid_1's rmse: 3.64591
# [2000]	training's rmse: 2.94276	valid_1's rmse: 3.63954
# [2100]	training's rmse: 2.93195	valid_1's rmse: 3.63443
# [2200]	training's rmse: 2.92199	valid_1's rmse: 3.63089
# [2300]	training's rmse: 2.91356	valid_1's rmse: 3.62778
# [2400]	training's rmse: 2.9061	valid_1's rmse: 3.62532
# [2500]	training's rmse: 2.8991	valid_1's rmse: 3.62414
# [2600]	training's rmse: 2.89239	valid_1's rmse: 3.62208
# [2700]	training's rmse: 2.88603	valid_1's rmse: 3.62123
# [2800]	training's rmse: 2.88029	valid_1's rmse: 3.62031
# [2900]	training's rmse: 2.87327	valid_1's rmse: 3.61827
# [3000]	training's rmse: 2.86693	valid_1's rmse: 3.61647
# [3100]	training's rmse: 2.86179	valid_1's rmse: 3.61611
# [3200]	training's rmse: 2.85566	valid_1's rmse: 3.61408
# [3300]	training's rmse: 2.84978	valid_1's rmse: 3.61233
# [3400]	training's rmse: 2.84401	valid_1's rmse: 3.61279
# Early stopping, best iteration is:
# [3362]	training's rmse: 2.84629	valid_1's rmse: 3.61213
# *****
# 3.612134902784456
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.023162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.42901	valid_1's rmse: 3.9292
# [200]	training's rmse: 3.2966	valid_1's rmse: 3.74029
# [300]	training's rmse: 3.24023	valid_1's rmse: 3.63495
# [400]	training's rmse: 3.20202	valid_1's rmse: 3.5753
# [500]	training's rmse: 3.17548	valid_1's rmse: 3.53411
# [600]	training's rmse: 3.14846	valid_1's rmse: 3.50368
# [700]	training's rmse: 3.12563	valid_1's rmse: 3.48041
# [800]	training's rmse: 3.10636	valid_1's rmse: 3.46671
# [900]	training's rmse: 3.09158	valid_1's rmse: 3.45525
# [1000]	training's rmse: 3.07633	valid_1's rmse: 3.44378
# [1100]	training's rmse: 3.06306	valid_1's rmse: 3.42936
# [1200]	training's rmse: 3.04824	valid_1's rmse: 3.41509
# [1300]	training's rmse: 3.03575	valid_1's rmse: 3.40426
# [1400]	training's rmse: 3.02208	valid_1's rmse: 3.39411
# [1500]	training's rmse: 3.01031	valid_1's rmse: 3.38892
# [1600]	training's rmse: 2.9952	valid_1's rmse: 3.37861
# [1700]	training's rmse: 2.98389	valid_1's rmse: 3.37102
# [1800]	training's rmse: 2.97421	valid_1's rmse: 3.36502
# [1900]	training's rmse: 2.96281	valid_1's rmse: 3.35697
# [2000]	training's rmse: 2.9541	valid_1's rmse: 3.35264
# [2100]	training's rmse: 2.94565	valid_1's rmse: 3.3501
# [2200]	training's rmse: 2.9374	valid_1's rmse: 3.34867
# [2300]	training's rmse: 2.92895	valid_1's rmse: 3.34648
# [2400]	training's rmse: 2.92102	valid_1's rmse: 3.34375
# [2500]	training's rmse: 2.91436	valid_1's rmse: 3.34347
# [2600]	training's rmse: 2.90764	valid_1's rmse: 3.34219
# [2700]	training's rmse: 2.90055	valid_1's rmse: 3.33826
# [2800]	training's rmse: 2.89385	valid_1's rmse: 3.33502
# [2900]	training's rmse: 2.88764	valid_1's rmse: 3.33263
# [3000]	training's rmse: 2.88136	valid_1's rmse: 3.33102
# [3100]	training's rmse: 2.87545	valid_1's rmse: 3.33137
# Early stopping, best iteration is:
# [3026]	training's rmse: 2.8798	valid_1's rmse: 3.33028
# *****
# 3.3302824836998757
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018604 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.44233	valid_1's rmse: 3.93563
# [200]	training's rmse: 3.3053	valid_1's rmse: 3.76108
# [300]	training's rmse: 3.24746	valid_1's rmse: 3.65755
# [400]	training's rmse: 3.20685	valid_1's rmse: 3.59784
# [500]	training's rmse: 3.17683	valid_1's rmse: 3.56708
# [600]	training's rmse: 3.15297	valid_1's rmse: 3.54669
# [700]	training's rmse: 3.13226	valid_1's rmse: 3.53035
# [800]	training's rmse: 3.1136	valid_1's rmse: 3.52063
# [900]	training's rmse: 3.09897	valid_1's rmse: 3.51332
# [1000]	training's rmse: 3.0865	valid_1's rmse: 3.50921
# [1100]	training's rmse: 3.07338	valid_1's rmse: 3.50674
# [1200]	training's rmse: 3.05772	valid_1's rmse: 3.50439
# [1300]	training's rmse: 3.04144	valid_1's rmse: 3.49888
# [1400]	training's rmse: 3.03054	valid_1's rmse: 3.49684
# [1500]	training's rmse: 3.01925	valid_1's rmse: 3.4929
# [1600]	training's rmse: 3.00918	valid_1's rmse: 3.4889
# [1700]	training's rmse: 2.9961	valid_1's rmse: 3.48398
# [1800]	training's rmse: 2.984	valid_1's rmse: 3.47971
# [1900]	training's rmse: 2.9738	valid_1's rmse: 3.47739
# [2000]	training's rmse: 2.96411	valid_1's rmse: 3.47306
# [2100]	training's rmse: 2.95567	valid_1's rmse: 3.47025
# [2200]	training's rmse: 2.94689	valid_1's rmse: 3.46753
# [2300]	training's rmse: 2.93965	valid_1's rmse: 3.46602
# [2400]	training's rmse: 2.93208	valid_1's rmse: 3.46616
# Early stopping, best iteration is:
# [2341]	training's rmse: 2.93633	valid_1's rmse: 3.46531
# *****
# 3.465308222145599
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.022499 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.4561	valid_1's rmse: 3.74853
# [200]	training's rmse: 3.31591	valid_1's rmse: 3.66308
# [300]	training's rmse: 3.24929	valid_1's rmse: 3.61244
# [400]	training's rmse: 3.21014	valid_1's rmse: 3.59074
# [500]	training's rmse: 3.18235	valid_1's rmse: 3.57567
# [600]	training's rmse: 3.15815	valid_1's rmse: 3.56176
# [700]	training's rmse: 3.14021	valid_1's rmse: 3.55771
# [800]	training's rmse: 3.12327	valid_1's rmse: 3.55346
# [900]	training's rmse: 3.10599	valid_1's rmse: 3.54804
# [1000]	training's rmse: 3.08747	valid_1's rmse: 3.5414
# [1100]	training's rmse: 3.07455	valid_1's rmse: 3.53431
# [1200]	training's rmse: 3.06339	valid_1's rmse: 3.53153
# [1300]	training's rmse: 3.05141	valid_1's rmse: 3.52837
# [1400]	training's rmse: 3.03974	valid_1's rmse: 3.52461
# [1500]	training's rmse: 3.02857	valid_1's rmse: 3.52176
# [1600]	training's rmse: 3.01772	valid_1's rmse: 3.51915
# [1700]	training's rmse: 3.00589	valid_1's rmse: 3.5167
# [1800]	training's rmse: 2.99527	valid_1's rmse: 3.51357
# [1900]	training's rmse: 2.985	valid_1's rmse: 3.51161
# [2000]	training's rmse: 2.97519	valid_1's rmse: 3.50894
# [2100]	training's rmse: 2.96545	valid_1's rmse: 3.50737
# [2200]	training's rmse: 2.95703	valid_1's rmse: 3.50599
# [2300]	training's rmse: 2.94856	valid_1's rmse: 3.50374
# [2400]	training's rmse: 2.94035	valid_1's rmse: 3.50263
# [2500]	training's rmse: 2.93306	valid_1's rmse: 3.50204
# [2600]	training's rmse: 2.927	valid_1's rmse: 3.50156
# Early stopping, best iteration is:
# [2594]	training's rmse: 2.92726	valid_1's rmse: 3.50143
# *****
# 3.50143196290754
# /Users/ken/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034454 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 3.46224	valid_1's rmse: 3.5933
# [200]	training's rmse: 3.32582	valid_1's rmse: 3.50833
# [300]	training's rmse: 3.25964	valid_1's rmse: 3.47544
# [400]	training's rmse: 3.2198	valid_1's rmse: 3.45099
# [500]	training's rmse: 3.18971	valid_1's rmse: 3.43225
# [600]	training's rmse: 3.16548	valid_1's rmse: 3.42348
# [700]	training's rmse: 3.14743	valid_1's rmse: 3.41807
# [800]	training's rmse: 3.13011	valid_1's rmse: 3.41567
# [900]	training's rmse: 3.11184	valid_1's rmse: 3.41423
# [1000]	training's rmse: 3.09879	valid_1's rmse: 3.41164
# [1100]	training's rmse: 3.08372	valid_1's rmse: 3.41184
# [1200]	training's rmse: 3.06999	valid_1's rmse: 3.40749
# [1300]	training's rmse: 3.05777	valid_1's rmse: 3.40383
# [1400]	training's rmse: 3.04534	valid_1's rmse: 3.40054
# [1500]	training's rmse: 3.03436	valid_1's rmse: 3.39935
# [1600]	training's rmse: 3.02448	valid_1's rmse: 3.39717
# [1700]	training's rmse: 3.01498	valid_1's rmse: 3.39456
# [1800]	training's rmse: 3.00667	valid_1's rmse: 3.39311
# [1900]	training's rmse: 2.99833	valid_1's rmse: 3.3902
# [2000]	training's rmse: 2.98865	valid_1's rmse: 3.38777
# [2100]	training's rmse: 2.97956	valid_1's rmse: 3.38588
# [2200]	training's rmse: 2.97201	valid_1's rmse: 3.38505
# [2300]	training's rmse: 2.9625	valid_1's rmse: 3.3824
# [2400]	training's rmse: 2.95568	valid_1's rmse: 3.38231
# Early stopping, best iteration is:
# [2339]	training's rmse: 2.95965	valid_1's rmse: 3.38216
# *****
# 3.38216078211404
# CV score is 3.4762148073470622

# %%
df = pd.DataFrame([[2,3], [4,5], [2,3]])

# %%
df.drop_duplicates()
# Out:
#    0  1
# 0  2  3
# 1  4  5

# %%
df
# Out:
#    0  1
# 0  2  3
# 1  4  5
# 2  2  3
